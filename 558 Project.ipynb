# %% [markdown]
# # ABIO558 Assignment Check-In
#
# ### Project Goals:
# 1. Write markdown text describing the question and outlining your plan for analysis
# 2. Insert a snippet of code to load data
# 3. print() or visualization a command to view the data

# %% [markdown]
# ## Goal 1: Outline your plan for analysis

# %%
# Question: How does EspM regulate whiB6 expression in the recipient M. smegmatis strain MKD8?
# Data we have: RNA-seq data of the WT and espM deletion (KO) strains of MKD8
# Project Goal: To identify genes that are expressed differently when EspM is missing - want to make tables of significant changes in gene expression
# --> also want to look at the effect of espM deletion on the expression of other genes in the genome

# Plan for Analysis (in summary): Analyze MKD8 WT vs espM KO RNASeq data to determine gene expression differences
# --> conditions are WT and deletion of the espM gene. Looking for significant changes
# in expression of genes in the whiB6 regulon (and/or anywhere else in the genome)

# Outline:

# Pull out raw count data of each gene for each of the 4 samples

# Normalize raw count data and calculate p-values

# Bonferroni/Multiple testing correction
# Note: this gives corrected p-values to account for false significance

# Find ratio of KO/WT

# Make a log2 expression of the ratio

# logfold2 and then transform that into log2

# generate Volcano and MA plots for visualization

# %% [markdown]
# ## Goal 2: Make Code to Load Data

# %% [markdown]
# ### Step 1: Pull out the correct data columns
#
# 1) Import libraries
# 2) Find file path - check that it's correct
# 3) Load data with pandas
# 4) Pull out raw count columns for each of the 4 samples (note: rename columns - Biorep 1 = OLD, Biorep 2 = NEW)

# %%
# 1. Import Libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import scanpy
import anndata
import seaborn as sns
import skimage
from skimage.io import imread
from scipy import stats

# %%
# 2. Find file path

data_directory = 'C:/Users/denis/Downloads/'
filepath_mkd8 = os.path.join(data_directory, 'MKD8_KO_Rockhopper_data.csv')
os.path.exists(filepath_mkd8)
# Out:
# True

# %% [markdown]
# ### Goal 3: Visualize a command

# %%
# 3. Load data with pandas

reads_df = pd.read_csv(filepath_mkd8, index_col=0)
reads_df.head()
# Out:
#                      Translation Start  Translation Stop  Transcription Stop  \
# Transcription Start
# NaN                                1.0            1515.0                 NaN
# NaN                             1454.0            2071.0              2071.0
# 2072.0                          2109.0            3302.0              3302.0
# 3303.0                          3331.0            4224.0              4224.0
# 4225.0                          4234.0            5388.0                 NaN
#
#                     Strand  Name     Synonym  \
# Transcription Start
# NaN                      +  dnaA  MSMEI_0001
# NaN                      +     -  MSMEI_0002
# 2072.0                   +  dnaN  MSMEI_0003
# 3303.0                   +     -  MSMEI_0004
# 4225.0                   +  recF  MSMEI_0005
#
#                                                             Product  \
# Transcription Start
# NaN                  chromosomal replication initiator protein dnaA
# NaN                                            hypothetical protein
# 2072.0                              DNA polymerase III subunit beta
# 3303.0                             6-phosphogluconate dehydrogenase
# 4225.0                      DNA replication and repair protein RecF
#
#                      Raw Counts MKD8-oldmycospike  \
# Transcription Start
# NaN                                        4093.0
# NaN                                        1969.0
# 2072.0                                    13295.0
# 3303.0                                     8056.0
# 4225.0                                     3001.0
#
#                      Normalized Counts MKD8-oldmycospike  \
# Transcription Start
# NaN                                             466488.0
# NaN                                             224415.0
# 2072.0                                         1515174.0
# 3303.0                                          918148.0
# 4225.0                                          342014.0
#
#                      RPKM MKD8-oldmycospike  ...  \
# Transcription Start                          ...
# NaN                                   232.0  ...
# NaN                                   274.0  ...
# 2072.0                                959.0  ...
# 3303.0                                776.0  ...
# 4225.0                                223.0  ...
#
#                      pValue MKD8-oldmycospike vs KOespM-OLDmycospike  \
# Transcription Start
# NaN                                                         0.047732
# NaN                                                         0.658421
# 2072.0                                                      0.169175
# 3303.0                                                      0.959884
# 4225.0                                                      0.428367
#
#                      qValue MKD8-oldmycospike vs KOespM-OLDmycospike  \
# Transcription Start
# NaN                                                              1.0
# NaN                                                              1.0
# 2072.0                                                           1.0
# 3303.0                                                           1.0
# 4225.0                                                           1.0
#
#                      pValue MKD8-oldmycospike vs KOespM-NEWmycospike  \
# Transcription Start
# NaN                                                         0.232398
# NaN                                                         0.715949
# 2072.0                                                      0.213948
# 3303.0                                                      0.349188
# 4225.0                                                      0.319915
#
#                      qValue MKD8-oldmycospike vs KOespM-NEWmycospike  \
# Transcription Start
# NaN                                                              1.0
# NaN                                                              1.0
# 2072.0                                                           1.0
# 3303.0                                                           1.0
# 4225.0                                                           1.0
#
#                      pValue MKD8-NEWmycospike vs KOespM-OLDmycospike  \
# Transcription Start
# NaN                                                         0.048318
# NaN                                                         0.665426
# 2072.0                                                      0.879587
# 3303.0                                                      0.585358
# 4225.0                                                      0.677851
#
#                      qValue MKD8-NEWmycospike vs KOespM-OLDmycospike  \
# Transcription Start
# NaN                                                              1.0
# NaN                                                              1.0
# 2072.0                                                           1.0
# 3303.0                                                           1.0
# 4225.0                                                           1.0
#
#                      pValue MKD8-NEWmycospike vs KOespM-NEWmycospike  \
# Transcription Start
# NaN                                                         0.069294
# NaN                                                         0.722310
# 2072.0                                                      0.287741
# 3303.0                                                      0.751938
# 4225.0                                                      0.699315
#
#                      qValue MKD8-NEWmycospike vs KOespM-NEWmycospike  \
# Transcription Start
# NaN                                                              1.0
# NaN                                                              1.0
# 2072.0                                                           1.0
# 3303.0                                                           1.0
# 4225.0                                                           1.0
#
#                      pValue KOespM-OLDmycospike vs KOespM-NEWmycospike  \
# Transcription Start
# NaN                                                       7.290000e-21
# NaN                                                       1.092048e-02
# 2072.0                                                    4.100000e-13
# 3303.0                                                    1.660000e-11
# 4225.0                                                    2.010000e-17
#
#                      qValue KOespM-OLDmycospike vs KOespM-NEWmycospike
# Transcription Start
# NaN                                                       4.220000e-19
# NaN                                                       5.016868e-02
# 2072.0                                                    2.510000e-12
# 3303.0                                                    9.370000e-11
# 4225.0                                                    2.650000e-16
#
# [5 rows x 35 columns]

# %%
# 4. extract the raw count columns

reads_df_2 = pd.read_csv(filepath_mkd8, usecols=['Raw Counts MKD8-oldmycospike', 'Raw Counts MKD8-NEWmycospike', 'Raw Counts KOespM-OLDmycospike', 'Raw Counts KOespM-NEWmycospike', 'Synonym'])
print(reads_df_2)

# do df.set index to name of synonym gene names
# Out:
#             Synonym  Raw Counts MKD8-oldmycospike  \
# 0        MSMEI_0001                        4093.0
# 1        MSMEI_0002                        1969.0
# 2        MSMEI_0003                       13295.0
# 3        MSMEI_0004                        8056.0
# 4        MSMEI_0005                        3001.0
# ...             ...                           ...
# 6886  predicted RNA                          75.0
# 6887     MSMEI_6749                        4085.0
# 6888     MSMEI_6750                        9695.0
# 6889     MSMEI_6751                        7317.0
# 6890     MSMEI_6752                        2700.0
#
#       Raw Counts MKD8-NEWmycospike  Raw Counts KOespM-OLDmycospike  \
# 0                           3700.0                          1442.0
# 1                           1744.0                           749.0
# 2                           9364.0                          4701.0
# 3                           5592.0                          4026.0
# 4                           1928.0                          1513.0
# ...                            ...                             ...
# 6886                          62.0                            27.0
# 6887                        3206.0                          1239.0
# 6888                        8156.0                          3126.0
# 6889                        6190.0                          2875.0
# 6890                        2637.0                          1314.0
#
#       Raw Counts KOespM-NEWmycospike
# 0                             1604.0
# 1                              650.0
# 2                             4894.0
# 3                             3617.0
# 4                             1542.0
# ...                              ...
# 6886                            30.0
# 6887                          1379.0
# 6888                          2869.0
# 6889                          3357.0
# 6890                          1426.0
#
# [6891 rows x 5 columns]

# %%
# Note: You can transpose (use ".T") to do scanpy functions - this inverts the rows and columns

# %%
# useful page for later in project: https://igb.mit.edu/mini-courses/python/data-processing-with-python/seaborn/visualizing-rnaseq-data
